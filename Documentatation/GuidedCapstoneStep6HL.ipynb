# %% [markdown]
# # Guided Capstone Step 6. Documentation

# %% [markdown]
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#
# 3.   Exploratory Data Analysis
#
# 4.   Pre-processing and Training Data Development
#
# 5.  Modeling
#
# 6.   **Documentation**
#   * Review the Results
#   * Finalize Code
#   * Finalize Documentation
#   * Create a Project Report
#   * Create a Slide Deck for the Executive Audience

# %% [markdown]
# In this guided capstone we are going to revisit many of the actions we took in the previous guided capstone steps. This gives you the opportunity to practice the code you wrote to solve the questions in step 4 and 5.

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df1 = pd.read_csv(r'C:/Users/muli2487/OneDrive - University of Idaho/U-Drive/Spring Board/Guided Capstone/1582673773_GuidedCapstone_Step2.ipynb/data/step3_output.csv', index_col = None)
df1.index = df1.Name
df1.head()
df1.drop('Name',axis = 1)
# Out:
#                                                 Region       state  \
# Name
# Hilltop Ski Area                                Alaska      Alaska
# Sunrise Park Resort                            Arizona     Arizona
# Yosemite Ski & Snowboard Area      Northern California  California
# Donner Ski Ranch                         Sierra Nevada  California
# June Mountain                            Sierra Nevada  California
# ...                                                ...         ...
# Hogadon Basin                                  Wyoming     Wyoming
# Sleeping Giant Ski Resort                      Wyoming     Wyoming
# Snow King Resort                               Wyoming     Wyoming
# Snowy Range Ski & Recreation Area              Wyoming     Wyoming
# White Pine Ski Area                            Wyoming     Wyoming
#
#                                    summit_elev  vertical_drop  base_elev  \
# Name
# Hilltop Ski Area                          2090            294       1796
# Sunrise Park Resort                      11100           1800       9200
# Yosemite Ski & Snowboard Area             7800            600       7200
# Donner Ski Ranch                          8012            750       7031
# June Mountain                            10090           2590       7545
# ...                                        ...            ...        ...
# Hogadon Basin                             8000            640       7400
# Sleeping Giant Ski Resort                 7428            810       6619
# Snow King Resort                          7808           1571       6237
# Snowy Range Ski & Recreation Area         9663            990       8798
# White Pine Ski Area                       9500           1100       8400
#
#                                    trams  fastEight  fastSixes  fastQuads  \
# Name
# Hilltop Ski Area                       0        0.0          0          0
# Sunrise Park Resort                    0        0.0          0          1
# Yosemite Ski & Snowboard Area          0        0.0          0          0
# Donner Ski Ranch                       0        0.0          0          0
# June Mountain                          0        0.0          0          2
# ...                                  ...        ...        ...        ...
# Hogadon Basin                          0        0.0          0          0
# Sleeping Giant Ski Resort              0        0.0          0          0
# Snow King Resort                       0        0.0          0          0
# Snowy Range Ski & Recreation Area      0        0.0          0          0
# White Pine Ski Area                    0        0.0          0          0
#
#                                    quad  ...  SkiableTerrain_ac  \
# Name                                     ...
# Hilltop Ski Area                      0  ...               30.0
# Sunrise Park Resort                   2  ...              800.0
# Yosemite Ski & Snowboard Area         0  ...               88.0
# Donner Ski Ranch                      0  ...              505.0
# June Mountain                         0  ...             1500.0
# ...                                 ...  ...                ...
# Hogadon Basin                         0  ...               92.0
# Sleeping Giant Ski Resort             0  ...              184.0
# Snow King Resort                      1  ...              400.0
# Snowy Range Ski & Recreation Area     0  ...               75.0
# White Pine Ski Area                   0  ...              370.0
#
#                                    Snow Making_ac  daysOpenLastYear  \
# Name
# Hilltop Ski Area                        30.000000        150.000000
# Sunrise Park Resort                     80.000000        115.000000
# Yosemite Ski & Snowboard Area          174.873239        110.000000
# Donner Ski Ranch                        60.000000        163.000000
# June Mountain                          174.873239        115.103943
# ...                                           ...               ...
# Hogadon Basin                           32.000000        121.000000
# Sleeping Giant Ski Resort               18.000000         61.000000
# Snow King Resort                       250.000000        121.000000
# Snowy Range Ski & Recreation Area       30.000000        131.000000
# White Pine Ski Area                    174.873239        115.103943
#
#                                    yearsOpen  averageSnowfall  AdultWeekday  \
# Name
# Hilltop Ski Area                        36.0             69.0     30.000000
# Sunrise Park Resort                     49.0            250.0     74.000000
# Yosemite Ski & Snowboard Area           84.0            300.0     47.000000
# Donner Ski Ranch                        82.0            400.0     75.000000
# June Mountain                           58.0            250.0     57.916957
# ...                                      ...              ...           ...
# Hogadon Basin                           61.0             80.0     48.000000
# Sleeping Giant Ski Resort               81.0            310.0     42.000000
# Snow King Resort                        80.0            300.0     59.000000
# Snowy Range Ski & Recreation Area       59.0            250.0     49.000000
# White Pine Ski Area                     81.0            150.0     57.916957
#
#                                    AdultWeekend  projectedDaysOpen  \
# Name
# Hilltop Ski Area                       34.00000         152.000000
# Sunrise Park Resort                    78.00000         104.000000
# Yosemite Ski & Snowboard Area          47.00000         107.000000
# Donner Ski Ranch                       75.00000         170.000000
# June Mountain                          64.16681         128.000000
# ...                                         ...                ...
# Hogadon Basin                          48.00000          95.000000
# Sleeping Giant Ski Resort              42.00000          77.000000
# Snow King Resort                       59.00000         123.000000
# Snowy Range Ski & Recreation Area      49.00000         120.053004
# White Pine Ski Area                    49.00000         120.053004
#
#                                    NightSkiing_ac  Clusters
# Name
# Hilltop Ski Area                             30.0         9
# Sunrise Park Resort                          80.0         0
# Yosemite Ski & Snowboard Area                 0.0         2
# Donner Ski Ranch                              0.0         2
# June Mountain                                 0.0         4
# ...                                           ...       ...
# Hogadon Basin                                 0.0         2
# Sleeping Giant Ski Resort                     0.0         2
# Snow King Resort                            110.0         8
# Snowy Range Ski & Recreation Area             0.0         4
# White Pine Ski Area                           0.0         4
#
# [167 rows x 25 columns]

# %%
X2 = df1.drop(['Name','Region','AdultWeekend','state'], axis =1)
X2
# Out:
#                                    summit_elev  vertical_drop  base_elev  \
# Name
# Hilltop Ski Area                          2090            294       1796
# Sunrise Park Resort                      11100           1800       9200
# Yosemite Ski & Snowboard Area             7800            600       7200
# Donner Ski Ranch                          8012            750       7031
# June Mountain                            10090           2590       7545
# ...                                        ...            ...        ...
# Hogadon Basin                             8000            640       7400
# Sleeping Giant Ski Resort                 7428            810       6619
# Snow King Resort                          7808           1571       6237
# Snowy Range Ski & Recreation Area         9663            990       8798
# White Pine Ski Area                       9500           1100       8400
#
#                                    trams  fastEight  fastSixes  fastQuads  \
# Name
# Hilltop Ski Area                       0        0.0          0          0
# Sunrise Park Resort                    0        0.0          0          1
# Yosemite Ski & Snowboard Area          0        0.0          0          0
# Donner Ski Ranch                       0        0.0          0          0
# June Mountain                          0        0.0          0          2
# ...                                  ...        ...        ...        ...
# Hogadon Basin                          0        0.0          0          0
# Sleeping Giant Ski Resort              0        0.0          0          0
# Snow King Resort                       0        0.0          0          0
# Snowy Range Ski & Recreation Area      0        0.0          0          0
# White Pine Ski Area                    0        0.0          0          0
#
#                                    quad  triple  double  ...  LongestRun_mi  \
# Name                                                     ...
# Hilltop Ski Area                      0       1       0  ...            1.0
# Sunrise Park Resort                   2       3       1  ...            1.2
# Yosemite Ski & Snowboard Area         0       1       3  ...            0.4
# Donner Ski Ranch                      0       1       5  ...            1.5
# June Mountain                         0       0       4  ...            2.0
# ...                                 ...     ...     ...  ...            ...
# Hogadon Basin                         0       0       1  ...            0.6
# Sleeping Giant Ski Resort             0       1       1  ...            1.0
# Snow King Resort                      1       1       1  ...            1.0
# Snowy Range Ski & Recreation Area     0       1       3  ...            0.7
# White Pine Ski Area                   0       2       0  ...            0.4
#
#                                    SkiableTerrain_ac  Snow Making_ac  \
# Name
# Hilltop Ski Area                                30.0       30.000000
# Sunrise Park Resort                            800.0       80.000000
# Yosemite Ski & Snowboard Area                   88.0      174.873239
# Donner Ski Ranch                               505.0       60.000000
# June Mountain                                 1500.0      174.873239
# ...                                              ...             ...
# Hogadon Basin                                   92.0       32.000000
# Sleeping Giant Ski Resort                      184.0       18.000000
# Snow King Resort                               400.0      250.000000
# Snowy Range Ski & Recreation Area               75.0       30.000000
# White Pine Ski Area                            370.0      174.873239
#
#                                    daysOpenLastYear  yearsOpen  \
# Name
# Hilltop Ski Area                         150.000000       36.0
# Sunrise Park Resort                      115.000000       49.0
# Yosemite Ski & Snowboard Area            110.000000       84.0
# Donner Ski Ranch                         163.000000       82.0
# June Mountain                            115.103943       58.0
# ...                                             ...        ...
# Hogadon Basin                            121.000000       61.0
# Sleeping Giant Ski Resort                 61.000000       81.0
# Snow King Resort                         121.000000       80.0
# Snowy Range Ski & Recreation Area        131.000000       59.0
# White Pine Ski Area                      115.103943       81.0
#
#                                    averageSnowfall  AdultWeekday  \
# Name
# Hilltop Ski Area                              69.0     30.000000
# Sunrise Park Resort                          250.0     74.000000
# Yosemite Ski & Snowboard Area                300.0     47.000000
# Donner Ski Ranch                             400.0     75.000000
# June Mountain                                250.0     57.916957
# ...                                            ...           ...
# Hogadon Basin                                 80.0     48.000000
# Sleeping Giant Ski Resort                    310.0     42.000000
# Snow King Resort                             300.0     59.000000
# Snowy Range Ski & Recreation Area            250.0     49.000000
# White Pine Ski Area                          150.0     57.916957
#
#                                    projectedDaysOpen  NightSkiing_ac  Clusters
# Name
# Hilltop Ski Area                          152.000000            30.0         9
# Sunrise Park Resort                       104.000000            80.0         0
# Yosemite Ski & Snowboard Area             107.000000             0.0         2
# Donner Ski Ranch                          170.000000             0.0         2
# June Mountain                             128.000000             0.0         4
# ...                                              ...             ...       ...
# Hogadon Basin                              95.000000             0.0         2
# Sleeping Giant Ski Resort                  77.000000             0.0         2
# Snow King Resort                          123.000000           110.0         8
# Snowy Range Ski & Recreation Area         120.053004             0.0         4
# White Pine Ski Area                       120.053004             0.0         4
#
# [167 rows x 22 columns]

# %%
y2 = df1.loc[:,'AdultWeekend']

# %%
import random
random.seed(30)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(X2)

# %%
from sklearn.model_selection import train_test_split
# Get the 1-dimensional flattened array of our response variable y by calling the ravel() function on y
y2 = y2.ravel()
X_train, X_test, y_train, y_test = train_test_split(X2, y2,
                                                    test_size=0.25)

# %% [markdown]
# ## Fit Models with Training Dataset

# %% [markdown]
# **<font color='teal'> Using sklearn fit the model you chose in Guided Capstone 5 on your training dataset. This includes: creating dummy features for states if you need them, scaling the data,and creating train and test splits before fitting the chosen model.Also, remember to generate a model performance score(MAE, or explained variance) based on the testing hold-out data set.</font>**

# %% [markdown]
# #### Best Model

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(random_state=0, n_estimators=500,max_features= 10, min_samples_leaf= 3, min_samples_split= 2)
regressor.fit(X_train, y_train)
regressor.score(X_test, y_test)
# Out:
# 0.7043301108210395

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {"n_estimators": [200, 500],
 "max_depth": [3, None],
 "max_features": [1, 3, 5, 10],
 "min_samples_split": [2, 5, 10],
 "min_samples_leaf": [1, 3, 10],
 "bootstrap": [True, False]}
model = RandomForestRegressor(random_state=0)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1)
grid.fit(X_train, y_train)
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.6517918030041608
# {'bootstrap': False, 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 200}

# %%
# make class predictions for the testing set
y_train1_pred = regressor.predict(X2)
y_test1_pred = regressor.predict(X_test)
print(y_train1_pred)
# Out:
# [37.79309042 76.972776   50.25445705 75.97576805 62.25197855 55.14084741
#  85.01380237 80.82886793 52.13794605 68.10135974 80.88111435 71.04456531
#  58.35313446 75.614787   66.88218728 51.98286603 59.83731566 56.42795186
#  61.49113483 45.85095403 60.15940417 50.84111858 41.88890764 52.21385547
#  61.41562134 49.85511942 53.25006223 41.37527884 45.32366011 48.14823795
#  55.83285164 40.31617586 43.40596019 47.82381963 46.85101544 46.98406415
#  52.845341   39.8642143  66.94023331 70.69123399 63.45700597 46.15251418
#  40.43585984 57.79774663 49.48427846 46.06786836 58.93859841 50.19471226
#  54.15485913 61.66343099 55.72353863 40.45232089 50.82466155 53.12346133
#  52.68067148 41.47799514 43.22993894 45.29655127 58.00805894 47.60396362
#  46.31366752 49.8101131  38.80748135 56.8042367  44.88997913 47.04756136
#  63.22567841 50.68127189 45.8520024  43.82469188 52.61798738 49.91900279
#  68.92573118 86.33694232 58.84773267 64.46612384 56.63765054 84.93596006
#  49.82125348 83.98873648 67.23158317 87.32412257 48.39197461 85.2783106
#  58.7568061  80.32802025 45.50807898 53.33883551 80.66443984 52.64939121
#  81.62295205 67.38812397 47.80707813 62.75192297 41.79493063 66.76856241
#  60.22528412 41.54354993 47.59926343 48.3832227  50.57196124 62.75438511
#  47.87821431 50.34215068 59.89721076 56.90880719 54.55984602 55.29745361
#  60.19772041 44.82728562 53.83156248 61.73655164 60.88782543 46.69628883
#  47.4259403  49.47959026 50.90234482 48.16206101 42.06593113 53.75468779
#  59.84991297 63.97848668 64.74923166 58.7495179  36.93226361 63.73614178
#  45.16847845 65.17606221 60.65927599 48.65563571 60.40493948 57.53704579
#  55.91382492 53.12367148 76.60299101 54.77366046 74.87277178 85.11552617
#  76.82551816 62.5257515  76.78721586 82.85061155 62.10023703 57.98287775
#  61.26652188 62.61763595 51.27884728 56.7775181  72.28135997 65.2881664
#  80.43040407 66.66738755 63.07647575 41.40992998 57.44190771 43.45069582
#  42.57752832 56.94123611 53.21034551 43.59088211 54.91588441 61.37800558
#  54.78808477 51.51614837 61.19765484 52.0649885  53.05043607]

# %%
from sklearn.metrics import explained_variance_score,mean_absolute_error
explained_variance_score(y_test, y_test1_pred)
# Out:
# 0.7411133296061669

# %%
mean_absolute_error(y_test, y_test1_pred)
# Out:
# 6.876900069136835

# %% [markdown]
# ## Review the results

# %% [markdown]
# **<font color='teal'> Now, let's predict the Big Mountain Weekend price with our model in order to provide a recommendation to our managers on how to price the `AdultWeekend` lift ticket. First we need to find the row for Big Mountain resort in our data using string contains or string matching.</font>**

# %%
df1[df1['Name'].str.contains('Big Mountain')]
# Out:
# Empty DataFrame
# Columns: [Name, Region, state, summit_elev, vertical_drop, base_elev, trams, fastEight, fastSixes, fastQuads, quad, triple, double, total_chairs, Runs, LongestRun_mi, SkiableTerrain_ac, Snow Making_ac, daysOpenLastYear, yearsOpen, averageSnowfall, AdultWeekday, AdultWeekend, projectedDaysOpen, NightSkiing_ac, Clusters]
# Index: []
#
# [0 rows x 26 columns]

# %%
df1.shape
# Out:
# (167, 26)

# %% [markdown]
# **<font color='teal'> Prepare the Big Mountain resort data row as you did in the model fitting stage.</font>**

# %%
Finalpre = df1
Finalpre['AdultWeekendPredicted'] = y_train1_pred
Finalpre['AdultWeekend'] = df1.AdultWeekend
Finalpre.head()
Finalpre.loc['Hilltop Ski Area']
# Out:
# Name                     Hilltop Ski Area
# Region                             Alaska
# state                              Alaska
# summit_elev                          2090
# vertical_drop                         294
# base_elev                            1796
# trams                                   0
# fastEight                               0
# fastSixes                               0
# fastQuads                               0
# quad                                    0
# triple                                  1
# double                                  0
# total_chairs                            3
# Runs                                   13
# LongestRun_mi                           1
# SkiableTerrain_ac                      30
# Snow Making_ac                         30
# daysOpenLastYear                      150
# yearsOpen                              36
# averageSnowfall                        69
# AdultWeekday                           30
# AdultWeekend                           34
# projectedDaysOpen                     152
# NightSkiing_ac                         30
# Clusters                                9
# AdultWeekendPredicted             37.7931
# Name: Hilltop Ski Area, dtype: object

# %%
print(df1.loc['Hilltop Ski Area'])
# Out:
# Name                     Hilltop Ski Area
# Region                             Alaska
# state                              Alaska
# summit_elev                          2090
# vertical_drop                         294
# base_elev                            1796
# trams                                   0
# fastEight                               0
# fastSixes                               0
# fastQuads                               0
# quad                                    0
# triple                                  1
# double                                  0
# total_chairs                            3
# Runs                                   13
# LongestRun_mi                           1
# SkiableTerrain_ac                      30
# Snow Making_ac                         30
# daysOpenLastYear                      150
# yearsOpen                              36
# averageSnowfall                        69
# AdultWeekday                           30
# AdultWeekend                           34
# projectedDaysOpen                     152
# NightSkiing_ac                         30
# Clusters                                9
# AdultWeekendPredicted             37.7931
# Name: Hilltop Ski Area, dtype: object

# %%
print(df1.loc['Hilltop Ski Area'])
# Out:
# Name                     Hilltop Ski Area
# Region                             Alaska
# state                              Alaska
# summit_elev                          2090
# vertical_drop                         294
# base_elev                            1796
# trams                                   0
# fastEight                               0
# fastSixes                               0
# fastQuads                               0
# quad                                    0
# triple                                  1
# double                                  0
# total_chairs                            3
# Runs                                   13
# LongestRun_mi                           1
# SkiableTerrain_ac                      30
# Snow Making_ac                         30
# daysOpenLastYear                      150
# yearsOpen                              36
# averageSnowfall                        69
# AdultWeekday                           30
# AdultWeekend                           34
# projectedDaysOpen                     152
# NightSkiing_ac                         30
# Clusters                                9
# AdultWeekendPredicted             37.7931
# Name: Hilltop Ski Area, dtype: object

# %% [markdown]
# **<font color='teal'> Predict the Big Mountain resort `Adult Weekend` price and print it out.</font>** This is our expected price to present to management. Based on our model given the characteristics of the resort in comparison to other ski resorts and their unique characteristics.

# %%
print(df1.loc['Hilltop Ski Area', 'AdultWeekendPredicted'])
# Out:
# 37.79309042211671

# %% [markdown]
# **<font color='teal'> Print the Big Mountain resort actual `Adult Weekend` price.</font>**

# %%
print(df1.loc['Hilltop Ski Area', 'AdultWeekend'])
# Out:
# 34.0

# %% [markdown]
# **<font color='teal'> As part of reviewing the results it is an important step to generate figures to visualize the data story. We can use the clusters we added to our data frame to create scatter plots for visualizing the Adult Weekend values compared to other characteristics. Run the example below to get you started and build two or three more figures to include in your data story telling.</font>**

# %%
plt.scatter(df1['summit_elev'], df1['vertical_drop'], c=df1['Clusters'], s=50, cmap='viridis', label ='clusters')
#plt.scatter(df1['summit_elev'], df1['vertical_drop'], c='black', s=100)
plt.xlabel('summit_elev')
plt.ylabel('vertical_drop')
plt.title('summit_elev by vertical_drop by cluster')
plt.savefig('figures/fig1.png',bbox_inches='tight')

# %% [markdown]
# ## Finalize Code

# %% [markdown]
#  Making sure our code is well organized and easy to follow is an important step. This is the time where you need to review the notebooks and Python scripts you've created and clean them up so they are easy to follow and succinct in nature. Addtionally, we will also save our final model as a callable object using Pickle for future use in a data pipeline. Pickle is a module that serializes (and de-serializes) Python objects so that they can become executable objects like functions. It's used extensively in production environments where machine learning models are deployed on an industrial scale!**<font color='teal'> Run the example code below to save out your callable model. Notice that we save it in the models folder we created in our previous guided capstone step.</font>**

# %%
import pickle
s = pickle.dumps(model)
from joblib import dump, load
dump(model, 'models/regression_model_adultweekend.joblib')
# Out:
# ['models/regression_model_adultweekend.joblib']

# %% [markdown]
# ## Finalize Documentation

# %% [markdown]
# For model documentation, we want to save the model performance metrics as well as the features included in the final model. You could also save the model perfomance metrics and coefficients fo the other models you tried in case you want to refer to them later. **<font color='teal'> Create a dataframe containing the coefficients and the model performance metrics and save it out as a csv file, then upload it to your github repository.</font>**
